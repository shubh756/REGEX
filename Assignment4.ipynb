# %% [markdown]
# *   **#Task 4**
# *   **Registration/Referral id :** SIRSS2218
# *   **Full name :** Shrikrushnakumar Bhausaheb Sondge

# %% [markdown]
# **First, let’s import the necessary libraries and store the data in our system for analysis.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8505156c-a408-44ea-b06e-3aa8bd24cf91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8505156c-a408-44ea-b06e-3aa8bd24cf91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Russia_alcohol.csv to Russia_alcohol.csv

# %% [markdown]
# **Reading Dataset and displaying first 10 rows**

# %%
df = pd.read_csv('Russia_alcohol.csv')
df.head()
# Out:
#    year              region  wine  beer  vodka  champagne  brandy
# 0  1998  Republic of Adygea   1.9   8.8    3.4        0.3     0.1
# 1  1998          Altai Krai   3.3  19.2   11.3        1.1     0.1
# 2  1998         Amur Oblast   2.1  21.2   17.3        0.7     0.4
# 3  1998  Arkhangelsk Oblast   4.3  10.6   11.7        0.4     0.3
# 4  1998    Astrakhan Oblast   2.9  18.0    9.5        0.8     0.2

# %% [markdown]
# **Displaying last 10 rows**

# %%
df.tail()
# Out:
#       year                          region  wine  ...  vodka  champagne  brandy
# 1610  2016                Chuvash Republic   5.0  ...    7.7        0.7     0.4
# 1611  2016       Chukotka Autonomous Okrug   3.9  ...   11.6        1.8     1.1
# 1612  2016        Sakha (Yakutia) Republic   4.3  ...    8.2        1.8     0.5
# 1613  2016  Yamalo-Nenets Autonomous Okrug   4.5  ...    8.2        1.7     1.3
# 1614  2016                Yaroslavl Oblast  10.2  ...    8.9        1.4     1.0
#
# [5 rows x 7 columns]

# %% [markdown]
# **Displaying general information about our dataset**

# %%
df.shape
# Out:
# (1615, 7)

# %%
df.columns
# Out:
# Index(['year', 'region', 'wine', 'beer', 'vodka', 'champagne', 'brandy'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       1615 non-null   int64
#  1   region     1615 non-null   object
#  2   wine       1552 non-null   float64
#  3   beer       1557 non-null   float64
#  4   vodka      1554 non-null   float64
#  5   champagne  1552 non-null   float64
#  6   brandy     1549 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 88.4+ KB

# %% [markdown]
# **Checking for null values and handeling them**

# %%
df.isnull().sum()
# Out:
# year          0
# region        0
# wine         63
# beer         58
# vodka        61
# champagne    63
# brandy       66
# dtype: int64

# %%
avg = df['wine'].mean()
df['wine'].replace(np.nan, avg, inplace = True)

# %%
df['beer'].replace(np.nan, df['beer'].mean(), inplace = True)
df['vodka'].replace(np.nan, df['vodka'].mean(), inplace = True)
df['champagne'].replace(np.nan, df['champagne'].mean(), inplace = True)
df['brandy'].replace(np.nan, df['brandy'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# year         0
# region       0
# wine         0
# beer         0
# vodka        0
# champagne    0
# brandy       0
# dtype: int64

# %% [markdown]
# **Displaying Statistical  Insight about dataset**
# - This step should be performed for getting details about various statistical data like Mean, Standard Deviation, Median, Max Value, Min Value, Correlation.

# %%
df.describe()
# Out:
#               year         wine  ...    champagne       brandy
# count  1615.000000  1615.000000  ...  1615.000000  1615.000000
# mean   2007.000000     5.628144  ...     1.313177     0.526998
# std       5.478922     2.757757  ...     0.782227     0.391933
# min    1998.000000     0.100000  ...     0.100000     0.000000
# 25%    2002.000000     3.700000  ...     0.800000     0.200000
# 50%    2007.000000     5.500000  ...     1.200000     0.490000
# 75%    2012.000000     7.200000  ...     1.600000     0.700000
# max    2016.000000    18.100000  ...     5.560000     2.300000
#
# [8 rows x 6 columns]

# %%
df.corr()
# Out:
#                year      wine      beer     vodka  champagne    brandy
# year       1.000000  0.362547  0.381954 -0.414442   0.331368  0.482467
# wine       0.362547  1.000000  0.488506  0.277629   0.468570  0.553371
# beer       0.381954  0.488506  1.000000  0.195877   0.449912  0.454643
# vodka     -0.414442  0.277629  0.195877  1.000000   0.269099  0.211845
# champagne  0.331368  0.468570  0.449912  0.269099   1.000000  0.777372
# brandy     0.482467  0.553371  0.454643  0.211845   0.777372  1.000000

# %%
plt.style.use('seaborn-darkgrid')

# %% [markdown]
# **Showing heatmap for achieved correlation**
# - Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. Heatmap is also defined by the name of the shading matrix. Heatmaps in Seaborn can be plotted by using the seaborn.heatmap() function.

# %%
plt.figure(figsize = (12,10))
sns.heatmap(df.corr(), annot = True)

# %% [markdown]
# **Numeric-Numeric Analysis**
# Analyzing the two numeric variables from a dataset is known as numeric-numeric analysis. We can analyze it in three different ways.
# - Scatterplot
# - Pairplot
# - Barplot
# - Piechart
# - Lineplot

# %% [markdown]
# **Scatterplot**
# - The scatter plot is a mainstay of statistical visualization. It depicts the joint distribution of two variables using a cloud of points, where each point represents an observation in the dataset. This depiction allows the eye to infer a substantial amount of information about whether there is any meaningful relationship between them.

# %%
plt.figure(figsize = (30, 15))
plt.xticks(rotation = 90)
sns.scatterplot(x = 'region', y = 'vodka', hue = 'year', data = df)

# %%
plt.figure(figsize = (20, 20))
plt.xticks(rotation = 90)
sns.scatterplot(x = 'region', y = 'beer', hue = 'year', data = df)

# %% [markdown]
# **Pairplot**
# - A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.

# %%
sns.pairplot(data = df , vars = ['wine', 'vodka', 'brandy', 'champagne', 'beer'], hue = 'year')

# %% [markdown]
# **Barplot**
# - Barplot will show the relation between two numeric data

# %%
plt.figure(figsize = (15,10))
sns.barplot(df['year'],df['vodka'])

# %%
plt.figure(figsize = (15,10))
sns.barplot(df['year'],df['champagne'])

# %% [markdown]
# **Piechart**
# - A Pie Chart is a circular statistical plot that can display only one series of data.

# %%
plt.figure(figsize = (12,12))
x = [df['wine'].mean(), df['beer'].mean(),df['vodka'].mean(),df['champagne'].mean(),df['brandy'].mean()]
alcohol = ['Wine', 'Beer', 'Vodka', 'Champagne', 'Brandy']
plt.title('Mean of various alchols' , fontsize = 20)
plt.pie(x, labels = alcohol)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f880952d4d0>,
# ...
#  [Text(1.0656316107206822, 0.2728172836035947, 'Wine'),
#   Text(-1.0304047110921366, 0.385053413644303, 'Beer'),
#   Text(0.8482298904642654, -0.7003613730946193, 'Vodka'),
#   Text(1.0938938745127298, -0.11574191679563779, 'Champagne'),
#   Text(1.0996970835115625, -0.02581326240837751, 'Brandy')])

# %% [markdown]
# **Lineplot**
# - The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters. These parameters control what visual semantics are used to identify the different subsets.

# %%
plt.figure(figsize = (10, 5))
plt.style.use('seaborn-darkgrid')
sns.lineplot(data = df, x = 'year', y = 'wine', label = 'Wine')
sns.lineplot(data = df, x = 'year', y = 'beer', label = 'Beer')
sns.lineplot(data = df, x = 'year', y = 'vodka', label = 'Vodka')
sns.lineplot(data = df, x = 'year', y = 'champagne', label = 'Champagne')
sns.lineplot(data = df, x = 'year', y = 'brandy', label = 'Brandy')

# %%
cols = ['year', 'region', 'wine', 'beer', 'vodka', 'champagne', 'brandy']
X = df[cols]
Y = df[['year']]
X.head(10)
# Out:
#    year                     region  wine  beer  vodka  champagne  brandy
# 0  1998         Republic of Adygea   1.9   8.8    3.4        0.3     0.1
# 1  1998                 Altai Krai   3.3  19.2   11.3        1.1     0.1
# 2  1998                Amur Oblast   2.1  21.2   17.3        0.7     0.4
# 3  1998         Arkhangelsk Oblast   4.3  10.6   11.7        0.4     0.3
# 4  1998           Astrakhan Oblast   2.9  18.0    9.5        0.8     0.2
# 5  1998  Republic of Bashkortostan   1.8  17.5   10.7        0.9     0.2
# 6  1998            Belgorod Oblast   3.4  23.0   10.8        0.9     0.1
# 7  1998             Bryansk Oblast   3.4  32.4    9.7        0.5     0.1
# 8  1998       Republic of Buryatia   1.1   8.8   15.8        0.9     0.1
# 9  1998            Vladimir Oblast   1.5  16.6   16.8        0.5     0.1

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
cols = ['wine', 'beer', 'vodka', 'champagne', 'brandy']
X[cols] = sc.fit_transform(X[cols])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['region'] = le.fit_transform(X['region'])

# %%
X.head()
# Out:
#    year  region      wine      beer     vodka  champagne    brandy
# 0  1998      47 -1.352294 -1.704882 -1.673898  -1.295647 -1.089804
# 1  1998       0 -0.844478 -1.287295 -0.103132  -0.272609 -1.089804
# 2  1998       2 -1.279749 -1.206990  1.089854  -0.784128 -0.324130
# 3  1998       3 -0.481752 -1.632607 -0.023600  -1.167767 -0.579355
# 4  1998       4 -0.989568 -1.335478 -0.461028  -0.656249 -0.834580
